# %% [markdown]
# Processed 12-XX December 2021. Data are [here](https://www.covid19.admin.ch/en/vaccination/symptoms).  Documentation is [here](https://www.covid19.admin.ch/api/data/documentation). Code is [here](XXX).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
raw = pd.read_csv(os.path.join('bag_covid_19_data_csv_03_décembre_2021/data', 'COVID19Death_vaccpersons.csv'))
raw.date = pd.to_datetime(raw.date, infer_datetime_format=True)
print(raw.info())
raw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3100 entries, 0 to 3099
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                3100 non-null   datetime64[ns]
#  1   vaccine             3100 non-null   object
#  2   vaccination_status  3100 non-null   object
#  3   entries             3100 non-null   int64
#  4   sumTotal            3100 non-null   int64
#  5   pop                 2778 non-null   float64
#  6   inz_entries         2470 non-null   float64
#  7   inzsumTotal         0 non-null      float64
#  8   mean7d              3040 non-null   float64
#  9   inzmean7d           2422 non-null   float64
#  10  prct                2062 non-null   float64
#  11  prctSumTotal        3100 non-null   float64
#  12  prct_mean7d         1008 non-null   float64
#  13  geoRegion           3100 non-null   object
#  14  type                3100 non-null   object
#  15  type_variant        3100 non-null   object
#  16  data_completeness   3100 non-null   object
#  17  version             3100 non-null   object
# dtypes: datetime64[ns](1), float64(8), int64(2), object(7)
# memory usage: 436.1+ KB
# None
#            date  vaccine    vaccination_status  entries  sumTotal        pop  \
# 0    2021-01-27  moderna      fully_vaccinated        0         0      126.0
# 1    2021-01-28  moderna      fully_vaccinated        0         0      175.0
# 2    2021-01-29  moderna      fully_vaccinated        0         0      183.0
# 3    2021-01-30  moderna      fully_vaccinated        0         0        NaN
# 4    2021-01-31  moderna      fully_vaccinated        0         0        NaN
# ...         ...      ...                   ...      ...       ...        ...
# 3095 2021-12-01      all               unknown        5       754        NaN
# 3096 2021-12-02      all      fully_vaccinated        5       317  5741973.0
# 3097 2021-12-02      all  partially_vaccinated        0        82   139379.0
# 3098 2021-12-02      all        not_vaccinated        4      1001  2828003.0
# 3099 2021-12-02      all               unknown        1       755        NaN
#
#       inz_entries  inzsumTotal  mean7d  inzmean7d  prct  prctSumTotal  \
# 0            0.00          NaN     NaN        NaN   0.0          0.00
# 1            0.00          NaN     NaN        NaN   0.0          0.00
# 2            0.00          NaN     NaN        NaN   0.0          0.00
# 3             NaN          NaN     0.0        NaN   0.0          0.00
# 4             NaN          NaN     0.0        NaN   NaN          0.00
# ...           ...          ...     ...        ...   ...           ...
# 3095          NaN          NaN     NaN        NaN  25.0         35.15
# 3096         0.09          NaN     NaN        NaN  50.0         14.71
# 3097         0.00          NaN     NaN        NaN   0.0          3.81
# 3098         0.14          NaN     NaN        NaN  40.0         46.45
# 3099          NaN          NaN     NaN        NaN  10.0         35.03
#
#       prct_mean7d geoRegion          type type_variant data_completeness  \
# 0             NaN      CHFL  COVID19Death      vaccine           limited
# 1             NaN      CHFL  COVID19Death      vaccine           limited
# 2             NaN      CHFL  COVID19Death      vaccine           limited
# 3             NaN      CHFL  COVID19Death      vaccine           limited
# 4             NaN      CHFL  COVID19Death      vaccine           limited
# ...           ...       ...           ...          ...               ...
# 3095          NaN      CHFL  COVID19Death      vaccine      intermediate
# 3096          NaN      CHFL  COVID19Death      vaccine      intermediate
# 3097          NaN      CHFL  COVID19Death      vaccine      intermediate
# 3098          NaN      CHFL  COVID19Death      vaccine      intermediate
# 3099          NaN      CHFL  COVID19Death      vaccine      intermediate
#
#                   version
# 0     2021-12-03_07-52-50
# 1     2021-12-03_07-52-50
# 2     2021-12-03_07-52-50
# 3     2021-12-03_07-52-50
# 4     2021-12-03_07-52-50
# ...                   ...
# 3095  2021-12-03_07-52-50
# 3096  2021-12-03_07-52-50
# 3097  2021-12-03_07-52-50
# 3098  2021-12-03_07-52-50
# 3099  2021-12-03_07-52-50
#
# [3100 rows x 18 columns]

# %%
deaths = raw.loc[(raw['date'] > '2021-06-30') &
           (raw['vaccine']=='all') &
           (raw['data_completeness']=='intermediate') &
           ((raw['vaccination_status']=='fully_vaccinated') |
           (raw['vaccination_status']=='partially_vaccinated') |
           (raw['vaccination_status']=='not_vaccinated') |
           (raw['vaccination_status']=='unknown'))
           ,
           ('date', 'vaccination_status', 'inzmean7d')]
deaths
# Out:
#            date    vaccination_status  inzmean7d
# 2480 2021-07-01      fully_vaccinated        0.0
# 2481 2021-07-01  partially_vaccinated        0.0
# 2482 2021-07-01        not_vaccinated        0.0
# 2483 2021-07-01               unknown        NaN
# 2484 2021-07-02      fully_vaccinated        0.0
# ...         ...                   ...        ...
# 3095 2021-12-01               unknown        NaN
# 3096 2021-12-02      fully_vaccinated        NaN
# 3097 2021-12-02  partially_vaccinated        NaN
# 3098 2021-12-02        not_vaccinated        NaN
# 3099 2021-12-02               unknown        NaN
#
# [620 rows x 3 columns]
